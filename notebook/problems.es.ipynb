# %% [markdown]
# # Ejercicios de probabilidad

# %% [markdown]
# ## Ejercicio 1
#
# Dos dados se lanzan una vez y se observa el total obtenido. Usa una simulación para encontrar la probabilidad estimada de que la puntuación sea mayor a 7 o un número par. Una simulación es una repetición del mismo experimento multiples veces para observar su comportamiento:
#
# - Ejecuta el experimento 1000 veces (lanza 2 dados 1000 veces, y suma el número de ambos dados).
# - Lleva ua cuenta de los números y las veces que la suma fue mayor a 7 o un número par.
# - Divide el número del paso 2 entre el número de iteraciones(1000).

# %%
import random
import numpy as np

# definamos el numero total de veces que se realiza el experimeinto
Total_lanzamientos = 1000

# definamos el contador donde se ira acumulando los resultados que cumplan con 
# la condicion a evaluar
contador = 0

# Para simular cada lanzamiento como son un numero conocido
# es adecuado usar un for
for i in range(Total_lanzamientos): 

    # Simulacion del lanzamiento del dado 1
    dado1 = random.randint(1, 6)

    # Simulacion del lanzamiento del dado 2
    dado2 = random.randint(1, 6)
        
    # Suma de los resultados del lanzamiento para definir el primer evento de interes
    suma = dado1 + dado2
        
    # Condicional que permite acumular en el contador un evento positivo
    # El el evento suma par o suma mayor a 7
    if (suma % 2 == 0) or (suma > 7):
        contador = contador + 1

# Resultado de la probabilidad

Probabilidad = contador / Total_lanzamientos

print(f"La probabilidad de obtener un número par o mayor que 7 es: {np.round(Probabilidad*100, 2)}%")
# Out:
# La probabilidad de obtener un número par o mayor que 7 es: 68.1%

# %% [markdown]
# ## Ejercicio 2
#
# Una caja contiene 10 bolas blancas, 20 bolas rojas y 30 bolas verdes. Si tomamos 5 bolas de la caja reemplazándolas (tomando una bola, anotando el color y luego regresandola a la caja). Queremos saber la probabilidad de:
#
# 1. Tomar 3 blancas y 2 rojas.
# 2. Toas todas del mismo color.
#
# Ejecuta el experimento 1000 veces y calcula las probabilidades que mencionadas.

# %%
ball_box = {}

# Crea la cajas con las bolas
for i in range(60):
    if i < 10:
        ball_box[i] = "White"
    elif (i > 9) and (i < 30):
        ball_box[i] = "Red"
    else:
        ball_box[i] = "Green"

print(ball_box)
print(" ")            

# Definamos el total de veces que realizaremos el ensayo
Total_extracciones = 1000

# Definamos los contadores que acumularan las ocurrencia de los eventos que estamos
# interesados en cuantificar
contador1 = 0
contador2 = 0

# para 
for i in range(Total_extracciones):
    colors = []

    # Simulamos el evento de tomar 5 bolas
    for i in range(5):
         colors.append(ball_box[np.random.randint(0, 59)])

    # Trasnformamos en un objeto matriz de numpy para la seleccion 
    colors = np.array(colors)
        
    white_balls = sum(colors == "White")
    red_balls = sum(colors == "Red")
    green_balls = sum(colors == "Green")

    # Evento 1: tomar 3 bolas blancas y bolas rojas
    if (white_balls == 3) and (red_balls == 2):
            contador1 = contador1 + 1
        
    # Evento 2: Todas las bolas tomadas son del mismo color   
    if (white_balls == 5) or (red_balls == 5) or (green_balls == 5):
            contador2 = contador2 + 1
    

Probabilidad1 = contador1 / Total_extracciones
Probabilidad2 = contador2 / Total_extracciones

Probabilidades = tomar_bolas(1000)

print(f"La porobabilidad de tomar 3 bolas blancas y 2 bolas rojas es: {np.round(Probabilidad1 * 100, 2)}%")
print(f"La probabilidad qur todas las bolas sean del mismo color es: {np.round(Probabilidad2 * 100, 2)}%")
# Out:
# {0: 'White', 1: 'White', 2: 'White', 3: 'White', 4: 'White', 5: 'White', 6: 'White', 7: 'White', 8: 'White', 9: 'White', 10: 'Red', 11: 'Red', 12: 'Red', 13: 'Red', 14: 'Red', 15: 'Red', 16: 'Red', 17: 'Red', 18: 'Red', 19: 'Red', 20: 'Red', 21: 'Red', 22: 'Red', 23: 'Red', 24: 'Red', 25: 'Red', 26: 'Red', 27: 'Red', 28: 'Red', 29: 'Red', 30: 'Green', 31: 'Green', 32: 'Green', 33: 'Green', 34: 'Green', 35: 'Green', 36: 'Green', 37: 'Green', 38: 'Green', 39: 'Green', 40: 'Green', 41: 'Green', 42: 'Green', 43: 'Green', 44: 'Green', 45: 'Green', 46: 'Green', 47: 'Green', 48: 'Green', 49: 'Green', 50: 'Green', 51: 'Green', 52: 'Green', 53: 'Green', 54: 'Green', 55: 'Green', 56: 'Green', 57: 'Green', 58: 'Green', 59: 'Green'}
#
# La porobabilidad de tomar 3 bolas blancas y 2 bolas rojas es: 0.4%
# La probabilidad qur todas las bolas sean del mismo color es: 4.7%
